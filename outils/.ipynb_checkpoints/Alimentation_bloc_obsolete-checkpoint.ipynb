# %%
#%save Alimentation_bloc.py 14

# %%
from Kernel_BE import Kernel

class Alimentation_bloc () :
    """
    def __init__ (self,
                  index_data,
                  nom_variable,
                  ID_reference_min, # string
                  ID_reference_max, # string
                  taille_bloc, # int
                  arg_kernel,
                  isValeur = True,
                  isID = False,
                  isTrace = False,
                  )
        """
    def __init__ (self, arg) :
        self.index_data = arg ['index_data']
        self.nom_variable = arg ['nom_variable']
        self.ID_reference_min = int (arg['ID_reference_min'])
        self.ID_reference_max = int (arg['ID_reference_max'])
        self.taille_bloc = arg ['taille_bloc']
        self.isValeur = arg['isValeur']
        self.isID = arg['isID']
        self.isTrace = arg ['isTrace']
        
        arg_kernel = arg ['arg_kernel']
        self.ID_reference_base = arg_kernel ['_ID_reference_base']
        
        
        self.kernel = Kernel(arg_kernel)
        
    def alimentation_bloc (self,p__ID,):
        """
        fournit un dico des dico ( chacun  represente un evenement ou ligne )
        par ID ou non (fonction du parametre self.isID )
        
        pour ID_reference,  du debut, à fin en bloc (taille = self.bloc_taille (paramete systeme)
        
        """
        _liste_total = []
              
        _taille = len(self.ID_reference_base) # taille du string ( valeur max des evenements)
        _isFirst = self.isTrace
        
        for _debut_bloc in range(self.ID_reference_min,
                                self.ID_reference_max ,
                                self.taille_bloc ) :
            
            _fin_bloc = _debut_bloc + self.taille_bloc
            if _fin_bloc > self.ID_reference_max :
                _fin_bloc = self.ID_reference_max 

            
            _debut_bloc_string = (self.ID_reference_base + str(_debut_bloc)) [_taille:]
            _fin_bloc_string = (self.ID_reference_base + str(_fin_bloc)) [_taille:]
            _isFirst = self.isTrace
            if _isFirst :
                print ("1 ________________________________________________________________")
                print ("debut_bloc = ", _debut_bloc)
                print ("fin_bloc =", _fin_bloc )
                print ("debut_bloc_string = ", _debut_bloc_string)
                print ("fin_bloc_string =", _fin_bloc_string )
                print ("self.nom_variable =",self.nom_variable)
                print ("self.isValeur =", self.isValeur)
                print ("self.taille_bloc =", self.taille_bloc)

            taille_lu, _hits = self.kernel.search_par_bloc (self.index_data,
                                                           p__ID,
                                                           #self.nom_variable,
                                                          _debut_bloc_string,
                                                          _fin_bloc_string,
                                                           size = self.taille_bloc,
                                                          #isValeur = self.isValeur,
                                                           isID = self.isID,
                                                         )
            
            
            #reconstitution de l'evenement par ID_reference => ligne ... evenement
            # et mise au fur et à mesure dans dico_globale par ID_reference
            if len(_hits) == 0  :
                print ('#######  pas de hits ?#', p__ID)
                continue
                
            
            
            _ID_reference_courant = _hits[0] ['_source'] ['ID_reference']
            _evenement = {}
            _liste_global = []
            for _hit in _hits :
                                               
                _variable_lu = _hit ['_source']
                _nom_variable = _variable_lu ['nom_variable']
                _ID_reference = _variable_lu  ['ID_reference']
                
                if _ID_reference != _ID_reference_courant :
                    _liste_global.append(_evenement)
                    _ID_reference_courant = _ID_reference
                    _evenement = {}
                                                   
                _evenement [_nom_variable] = _variable_lu ['valeur']
                                    
                continue
                
            
            if _isFirst :
                if len(_liste_global) != 0:
                    #print ([enreg ['ID'] for enreg in _liste_global ])
                    print ("2 ________________________________________________________________")
                    print ("debut_bloc = ", _debut_bloc)
                    print ("fin_bloc_string =", _fin_bloc )
                    print ("debut_bloc_string = ", _debut_bloc_string)
                    print ("fin_bloc_string =", _fin_bloc_string )
                    print ("self.nom_variable =",self.nom_variable)
                    print ("self.isValeur =", self.isValeur)
                    print ("self.taille_bloc =", self.taille_bloc)
                    _isFirst = False
                    
                    
                    
            _liste_total.extend(_liste_global)
            print ("remplissage = ", len(_liste_global))
            print ()
            continue
            
               
        return _liste_total

# %%
# test 
import time
from datetime import datetime
#from Alimentation_bloc import Alimentation_bloc

arg_kernel = {  
          "createur" : "generic", 
          "date_emetteur" : str(datetime.now()),
          "http_auth" : None,
          "timeout" : 10,
          "host" : "localhost", 
          "port" : 9200 ,
          "zipChoisi" : 'bz2',
          "index_log_error" : "trace1",
          "index_log_warning" : "trace2",
          "index_log_trace" : "trace3",
          "index_system" : "systeme",
          "isPurge_existing_index_log" : True,
          "extra_elasticsearch_args" : None,
          "trace" : False,
          "_ID_reference_base" : "000000000000000000000000000000",
    
         
                }
arg = {}
arg ['arg_kernel'] = arg_kernel

print ("# on recupere les donnes par valeurs pas besoin de ID")

arg['index_data'] = "data_fake_"
arg ['nom_variable'] = 'prix_panier'
arg ['ID_reference_min'] = 50
arg ['ID_reference_max'] = 100
arg ['taille_bloc'] = 10
arg ['isValeur'] = True # ne sert plus à rien ????
arg ['isTrace'] = True
arg ['isID'] = False



A = Alimentation_bloc (arg)
ID = ""
x = A.alimentation_bloc(ID) 


    

print ("\n\n# on recupere les donnes par dico pas besoin de ID")

#index_data = "data_fake_"
#nom_variable = 'prix_panier'
#ID_reference_min = 50
#ID_reference_max = 100
#taille_bloc = 10
arg ['isValeur'] = False # ne sert plus à rien ?
arg ['isID'] = False
#isTrace = True
#ID_reference_base = "000000000000000000000000000000"

A = Alimentation_bloc (arg)

ID = ""
liste = []
x = A.alimentation_bloc(ID) 
    
    
    


print ("\n\n# on recupere les donnes par dico sur un  ID")

#index_data = "data_fake_"
#nom_variable = 'prix_panier'
arg ['ID_reference_min'] = 0
arg ['ID_reference_max'] = 50
#taille_bloc = 10
arg ['isValeur'] = False
arg ['isID'] = True
#isTrace = True

#ID_reference_base = "000000000000000000000000000000"

A = Alimentation_bloc (arg)



ID = "homme_cadre_sup_0"
x = A.alimentation_bloc(ID) 
    

print ("\n\n# on recupere les donnes par valeurs  sur un  ID")


#index_data = "data_fake_"
#nom_variable = 'prix_panier'
arg ['ID_reference_min'] = 0
arg ['ID_reference_max'] = 1000
arg ['taille_bloc'] = 500
arg ['isValeur'] = True
arg ['isID'] = True
#isTrace = True

#ID_reference_base = "000000000000000000000000000000"

A = Alimentation_bloc (arg)
t = time.time()
ID = "homme_cadre_sup_0"
x = A.alimentation_bloc(ID) 

print ("nombre de ligne pour un  ID =", len(x))


arg ['ID_reference_min'] = 0
arg ['ID_reference_max'] = 1000
arg ['taille_bloc'] = 500
arg ['isValeur'] = True
arg ['isID'] = False


liste_total = A.alimentation_bloc(" ")
if len(liste_total) == 0  or not isinstance (liste_total, type([])):
    print ("########################### erreur de lecture ?")
print (liste_total [0])
print (liste_total [1])
print (liste_total [len(liste_total)-1])

print ()
print ('nombre lu =', len(liste_total))

print ()
print ("1000 variable lu en ", time.time() - t  , "sans ID qui a ", len(liste_total), " ligne")
# Out:
# # on recupere les donnes par valeurs pas besoin de ID
# 1 ________________________________________________________________
# debut_bloc =  50
# fin_bloc = 60
# debut_bloc_string =  50
# fin_bloc_string = 60
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  50
# fin_bloc_string = 60
# debut_bloc_string =  50
# fin_bloc_string = 60
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# remplissage =  1
#
# 1 ________________________________________________________________
# debut_bloc =  60
# fin_bloc = 70
# debut_bloc_string =  60
# fin_bloc_string = 70
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  60
# fin_bloc_string = 70
# debut_bloc_string =  60
# fin_bloc_string = 70
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# remplissage =  1
#
# 1 ________________________________________________________________
# debut_bloc =  70
# fin_bloc = 80
# debut_bloc_string =  70
# fin_bloc_string = 80
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  70
# fin_bloc_string = 80
# debut_bloc_string =  70
# fin_bloc_string = 80
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# remplissage =  1
#
# 1 ________________________________________________________________
# debut_bloc =  80
# fin_bloc = 90
# debut_bloc_string =  80
# fin_bloc_string = 90
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  80
# fin_bloc_string = 90
# debut_bloc_string =  80
# fin_bloc_string = 90
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# remplissage =  1
#
# 1 ________________________________________________________________
# debut_bloc =  90
# fin_bloc = 100
# debut_bloc_string =  90
# fin_bloc_string = 100
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  90
# fin_bloc_string = 100
# debut_bloc_string =  90
# fin_bloc_string = 100
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 10
# remplissage =  1
#
#
#
# # on recupere les donnes par dico pas besoin de ID
# 1 ________________________________________________________________
# debut_bloc =  50
# fin_bloc = 60
# debut_bloc_string =  50
# fin_bloc_string = 60
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  50
# fin_bloc_string = 60
# debut_bloc_string =  50
# fin_bloc_string = 60
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# remplissage =  1
#
# 1 ________________________________________________________________
# debut_bloc =  60
# fin_bloc = 70
# debut_bloc_string =  60
# fin_bloc_string = 70
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  60
# fin_bloc_string = 70
# debut_bloc_string =  60
# fin_bloc_string = 70
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# remplissage =  1
#
# 1 ________________________________________________________________
# debut_bloc =  70
# fin_bloc = 80
# debut_bloc_string =  70
# fin_bloc_string = 80
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  70
# fin_bloc_string = 80
# debut_bloc_string =  70
# fin_bloc_string = 80
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# remplissage =  1
#
# 1 ________________________________________________________________
# debut_bloc =  80
# fin_bloc = 90
# debut_bloc_string =  80
# fin_bloc_string = 90
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  80
# fin_bloc_string = 90
# debut_bloc_string =  80
# fin_bloc_string = 90
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# remplissage =  1
#
# 1 ________________________________________________________________
# debut_bloc =  90
# fin_bloc = 100
# debut_bloc_string =  90
# fin_bloc_string = 100
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  90
# fin_bloc_string = 100
# debut_bloc_string =  90
# fin_bloc_string = 100
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# remplissage =  1
#
#
#
# # on recupere les donnes par dico sur un  ID
# 1 ________________________________________________________________
# debut_bloc =  0
# fin_bloc = 10
# debut_bloc_string =  0
# fin_bloc_string = 10
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# 2 ________________________________________________________________
# debut_bloc =  0
# fin_bloc_string = 10
# debut_bloc_string =  0
# fin_bloc_string = 10
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# remplissage =  1
#
# 1 ________________________________________________________________
# debut_bloc =  10
# fin_bloc = 20
# debut_bloc_string =  10
# fin_bloc_string = 20
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# #######  pas de hits ?# homme_cadre_sup_0
# 1 ________________________________________________________________
# debut_bloc =  20
# fin_bloc = 30
# debut_bloc_string =  20
# fin_bloc_string = 30
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# #######  pas de hits ?# homme_cadre_sup_0
# 1 ________________________________________________________________
# debut_bloc =  30
# fin_bloc = 40
# debut_bloc_string =  30
# fin_bloc_string = 40
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# #######  pas de hits ?# homme_cadre_sup_0
# 1 ________________________________________________________________
# debut_bloc =  40
# fin_bloc = 50
# debut_bloc_string =  40
# fin_bloc_string = 50
# self.nom_variable = prix_panier
# self.isValeur = False
# self.taille_bloc = 10
# #######  pas de hits ?# homme_cadre_sup_0
#
#
# # on recupere les donnes par valeurs  sur un  ID
# 1 ________________________________________________________________
# debut_bloc =  0
# fin_bloc = 500
# debut_bloc_string =  0
# fin_bloc_string = 500
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 500
# 2 ________________________________________________________________
# debut_bloc =  0
# fin_bloc_string = 500
# debut_bloc_string =  0
# fin_bloc_string = 500
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 500
# remplissage =  10
#
# 1 ________________________________________________________________
# debut_bloc =  500
# fin_bloc = 1000
# debut_bloc_string =  500
# fin_bloc_string = 1000
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 500
# #######  pas de hits ?# homme_cadre_sup_0
# nombre de ligne pour un  ID = 10
# 1 ________________________________________________________________
# debut_bloc =  0
# fin_bloc = 500
# debut_bloc_string =  0
# fin_bloc_string = 500
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 500
# #######  pas de hits ?#
# 1 ________________________________________________________________
# debut_bloc =  500
# fin_bloc = 1000
# debut_bloc_string =  500
# fin_bloc_string = 1000
# self.nom_variable = prix_panier
# self.isValeur = True
# self.taille_bloc = 500
# #######  pas de hits ?#
# ########################### erreur de lecture ?
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-6f8f3b90579a> in <module>
#     121 if len(liste_total) == 0  or not isinstance (liste_total, type([])):
#     122     print ("########################### erreur de lecture ?")
# --> 123 print (liste_total [0])
#     124 print (liste_total [1])
#     125 print (liste_total [len(liste_total)-1])
#
# IndexError: list index out of range

# %%
print (len(liste_total))
# Out:
# 0
